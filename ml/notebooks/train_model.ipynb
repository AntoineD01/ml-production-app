# %%
import os
import mlflow
import mlflow.sklearn
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import joblib

# %%
os.environ["MLFLOW_TRACKING_USERNAME"] = "AntoineD01"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "cee1e5d634039f04fec9557111b9cd11708f022a"

# %%
mlflow.set_tracking_uri("https://dagshub.com/AntoineD01/ml-production-app.mlflow")

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
with mlflow.start_run():
    # Log parameters
    mlflow.log_params(model.get_params())
    # Optionally, log metrics (example: accuracy on test set)
    accuracy = model.score(X_test, y_test)
    mlflow.log_metric("accuracy", accuracy)
    # Model logging is skipped due to unsupported endpoint on DagsHub
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 with mlflow.start_run():
#       2     # Log parameters
#       3     mlflow.log_params(model.get_params())
#       4     # Optionally, log metrics (example: accuracy on test set)
#
# File c:\Python311\Lib\site-packages\mlflow\tracking\fluent.py:379, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     377 experiment_id = str(experiment_id) if isinstance(experiment_id, int) else experiment_id
#     378 if len(active_run_stack) > 0 and not nested:
# --> 379     raise Exception(
#     380         (
#     381             "Run with UUID {} is already active. To start a new run, first end the "
#     382             + "current run with mlflow.end_run(). To start a nested "
#     383             + "run, call start_run with nested=True"
# ...

# %%
# Save to file
joblib.dump(model, "iris_model.pkl")

# Log as an artifact
mlflow.log_artifact("iris_model.pkl")
